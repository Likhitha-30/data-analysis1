# %% [markdown]
# Seaborn is a library that uses matplotlib underneath to plotgraphs.

# %%
#importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns .get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#!pip install seaborn --upgrade
df= sns.load_dataset("tips")
df
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# 1.import necessary library
# 2.import dataframe
# 3.basic checks on data:shape of your data,no.of col,rows
# 4.name of the col
# 5. two statistical methods analysis with deccribe function

# %%
print(df.shape)
# Out:
# (244, 7)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
float:64,32,16 float
numerical:64,32,16,8 integers
category:obj,
date time:no spaces date nd time
may bet boolean records:true or false
implement discription:for numerical col
# Out:
#   Cell In[14], line 1
#     float:64,32,16 float
#             ^
# SyntaxError: invalid syntax

# %%
df.describe()
# gives only about total_bill,tip,size
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [markdown]
# Insights:
# 1.Higher bills usually get higher tips
# Customers with a larger total_bill tend to leave a higher tip, showing a positive relationship between bill amount and tipping.
# 2.Dinner time dominates the data
# Most transactions occur during Dinner, indicating higher customer flow and spending compared to Lunch.
# 3.Weekends are busier than weekdays
# Saturday and Sunday have more records than other days, meaning restaurants get more customers on weekends.
# 4.Non-smokers are more common than smokers
# The majority of customers are Non-smokers, suggesting fewer smokers dine in this restaurant.
# 5.Small groups visit more frequently
# Most tables have a size of 2 or 3, showing couples and small groups are the most common visitors.

# %%
Baisc checks:
in basic checks we analyse data sets with its position

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# from
# #Null values treatment and imputation.
# A.Fill the missing records
#     1.mean median mode
#     2.domain
# B.Remove the missing data:
#     1.Remove the rows in which missing imputation
#            dropna data loss less than 20 % then remove
#
#     2.Remove the col in which missing positions
#        tip col we have the missing
#
#       #!pip install seaborn --upgrade
#      df= sns.load_dataset("tips")
#      df

# %% [markdown]
# tip 100
# tip(100/244)*100 =40
# smoker 50/244*100=20.5

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df.shape[0]
# Out:
# 244

# %%
#!pip install seaborn --upgrade
df= sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='category')
# Out:
#         class deck
# count     891  203
# unique      3    7
# top     Third    C
# freq      491   59

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.dropna()
# temp method
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
df.dropna().shape
# Out:
# (182, 15)

# %%
df.shape
# actual rows n col
# Out:
# (891, 15)

# %%
( (df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# Out:
# 79.57351290684625

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# deck percent of missing records is more than 20 or it is 77 percent  we can remove deck
# age - np.median
# embark_town mode
# embarked median

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df['age'].fillna(df['age'].median(), inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\Ki\AppData\Local\Temp\ipykernel_14236\200565503.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)
# C:\Users\Ki\AppData\Local\Temp\ipykernel_14236\200565503.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)
# C:\Users\Ki\AppData\Local\Temp\ipykernel_14236\200565503.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df['embarked_town'] = df['embarked_town'].fillna(df['emb'].median())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'embarked_town'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df['embarked_town'] = df['embarked_town'].fillna(df['emb'].median())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'embarked_town'

# %% [raw]
# unvariable Analysis
#
# numerical
# 1.histogram
#  categorical
# 1.countplot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
survived
pclass
sibsppar
parch
age
fare

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'])
plt.show()

# %% [markdown]
# # bivariate Analysis

# %%
1.Histogram: age ,gender

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'],hue=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'], y=df['age'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'], y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'], y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'], y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['survived'], y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'], y=df['sibsp'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'], y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'], y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['age'], y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'], y=df['parch'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'], y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['sibsp'], y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'], y=df['fare'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['parch'], y=df['pclass'])
plt.show()

# %%
plt.figure()
sns.scatterplot(x=df['fare'], y=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['sex'],estimator='median')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['sex'],estimator='std')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['embarked'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['adult_male'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['embark_town'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'], y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['embarked'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['adult_male'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['embark_town'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'], y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['embarked'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['adult_male'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['embark_town'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'], y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['embarked'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['adult_male'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['embark_town'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'], y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['embarked'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['adult_male'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['embark_town'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'], y=df['alone'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['sex'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['embarked'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['class'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['who'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['embark_town'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['alive'],estimator='mean')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'], y=df['alone'],estimator='mean')
plt.show()
